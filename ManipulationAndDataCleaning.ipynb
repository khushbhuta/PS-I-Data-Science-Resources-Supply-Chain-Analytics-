# %%
import numpy as np
import pandas as pd

# %%
retail = pd.read_csv("C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\online_retail2 (1).csv")

# %%
retail.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
retail.shape
# Out:
# (1067371, 8)

# %%
retail = retail.drop_duplicates()

# %%
retail.shape
# Out:
# (1033036, 8)

# %%
retail.Description.isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1067366    False
# 1067367    False
# 1067368    False
# 1067369    False
# 1067370    False
# Name: Description, Length: 1033036, dtype: bool

# %%
retail.Description.isnull().sum()
# Out:
# 4275

# %%
retail.isnull().sum().sum()
# Out:
# 239426

# %%
retail = retail.dropna(axis=0,how='any')

# %%
retail.shape
# Out:
# (797885, 8)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797885 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      797885 non-null  object
#  1   StockCode    797885 non-null  object
#  2   Description  797885 non-null  object
#  3   Quantity     797885 non-null  int64
#  4   InvoiceDate  797885 non-null  object
#  5   Price        797885 non-null  float64
#  6   Customer ID  797885 non-null  float64
#  7   Country      797885 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 54.8+ MB

# %%
retail.InvoiceDate
# Out:
# 0          2009-12-01 07:45:00
# 1          2009-12-01 07:45:00
# 2          2009-12-01 07:45:00
# 3          2009-12-01 07:45:00
# 4          2009-12-01 07:45:00
#                   ...
# 1067366    2011-12-09 12:50:00
# 1067367    2011-12-09 12:50:00
# 1067368    2011-12-09 12:50:00
# 1067369    2011-12-09 12:50:00
# 1067370    2011-12-09 12:50:00
# Name: InvoiceDate, Length: 797885, dtype: object

# %%
retail['date'] = pd.to_datetime(retail['InvoiceDate'])

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797885 entries, 0 to 1067370
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      797885 non-null  object
#  1   StockCode    797885 non-null  object
#  2   Description  797885 non-null  object
#  3   Quantity     797885 non-null  int64
#  4   InvoiceDate  797885 non-null  object
#  5   Price        797885 non-null  float64
#  6   Customer ID  797885 non-null  float64
#  7   Country      797885 non-null  object
#  8   date         797885 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 60.9+ MB

# %%
retail['date'].describe()
# Out:
# count                           797885
# mean     2011-01-02 13:17:34.141160704
# min                2009-12-01 07:45:00
# 25%                2010-07-02 09:47:00
# 50%                2010-12-02 12:33:00
# 75%                2011-07-31 15:50:00
# max                2011-12-09 12:50:00
# Name: date, dtype: object

# %%
retail.Country.value_counts()
# Out:
# Country
# United Kingdom          716115
# Germany                  17339
# EIRE                     16014
# France                   13897
# Netherlands               5137
# Spain                     3754
# Belgium                   3110
# Switzerland               3058
# Portugal                  2414
# Australia                 1890
# Channel Islands           1646
# Italy                     1507
# Sweden                    1343
# Norway                    1308
# Cyprus                    1157
# Finland                   1049
# Austria                    938
# Denmark                    797
# Greece                     663
# Japan                      565
# USA                        535
# Poland                     527
# Unspecified                521
# United Arab Emirates       386
# Singapore                  346
# Israel                     321
# Malta                      299
# Canada                     228
# Iceland                    222
# Lithuania                  154
# RSA                        123
# Brazil                      94
# Thailand                    76
# Korea                       63
# European Community          61
# Bahrain                     59
# West Indies                 54
# Lebanon                     45
# Czech Republic              30
# Nigeria                     30
# Saudi Arabia                10
# Name: count, dtype: int64

# %%
retail[(retail.Country == 'France') | (retail.Country == 'EIRE')].Country.value_counts()
# Out:
# Country
# EIRE      16014
# France    13897
# Name: count, dtype: int64

# %%
countries = ['France','EIRE','Spain']

# %%
retail[retail.Country.isin(countries)].Country.value_counts()
# Out:
# Country
# EIRE      16014
# France    13897
# Spain      3754
# Name: count, dtype: int64

# %%
retail.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'date'],
#       dtype='object')

# %%
retail[retail.date>='2011-Aug']
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 810882   561904     22075       6 RIBBONS ELEGANT CHRISTMAS         96
# 810883   561904    85049E          SCANDINAVIAN REDS RIBBONS       156
# 810884   561905     21385    IVORY HANGING DECORATION  HEART        24
# 810885   561905    84970L   SINGLE HEART ZINC T-LIGHT HOLDER        12
# 810886   561905    84970S  HANGING HEART ZINC T-LIGHT HOLDER        12
# ...         ...       ...                                ...       ...
# 1067366  581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138      BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                            POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  \
# 810882   2011-08-01 08:30:00   1.45      17941.0  United Kingdom
# 810883   2011-08-01 08:30:00   1.06      17941.0  United Kingdom
# 810884   2011-08-01 09:31:00   0.85      14947.0  United Kingdom
# 810885   2011-08-01 09:31:00   0.95      14947.0  United Kingdom
# 810886   2011-08-01 09:31:00   0.85      14947.0  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France
#
#                        date
# 810882  2011-08-01 08:30:00
# 810883  2011-08-01 08:30:00
# 810884  2011-08-01 09:31:00
# 810885  2011-08-01 09:31:00
# 810886  2011-08-01 09:31:00
# ...                     ...
# 1067366 2011-12-09 12:50:00
# 1067367 2011-12-09 12:50:00
# 1067368 2011-12-09 12:50:00
# 1067369 2011-12-09 12:50:00
# 1067370 2011-12-09 12:50:00
#
# [199446 rows x 9 columns]

# %%
retail[(retail.date>='2011-Aug-01') & (retail.date>='2011-Aug-30')]
# Out:
#          Invoice StockCode                          Description  Quantity  \
# 841626   C564748     23155  KNICKERBOCKERGLORY MAGNET ASSORTED         -6
# 841627   C564748     23211       RED ROCKING HORSE HAND PAINTED       -24
# 841628   C564748     23210     WHITE ROCKING HORSE HAND PAINTED       -24
# 841629   C564748     22978                   PANTRY ROLLING PIN        -5
# 841630   C564748     21672   WHITE SPOT RED CERAMIC DRAWER KNOB       -24
# ...          ...       ...                                  ...       ...
# 1067366   581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367   581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368   581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369   581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370   581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country                date
# 841626   2011-08-30 08:00:00   0.83      14911.0    EIRE 2011-08-30 08:00:00
# 841627   2011-08-30 08:00:00   1.25      14911.0    EIRE 2011-08-30 08:00:00
# 841628   2011-08-30 08:00:00   1.25      14911.0    EIRE 2011-08-30 08:00:00
# 841629   2011-08-30 08:00:00   3.75      14911.0    EIRE 2011-08-30 08:00:00
# 841630   2011-08-30 08:00:00   1.25      14911.0    EIRE 2011-08-30 08:00:00
# ...                      ...    ...          ...     ...                 ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France 2011-12-09 12:50:00
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France 2011-12-09 12:50:00
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France 2011-12-09 12:50:00
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France 2011-12-09 12:50:00
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France 2011-12-09 12:50:00
#
# [173270 rows x 9 columns]

# %%
retail['Country'][retail.Country=='EIRE'] = 'Eastern Ireland'
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\2064988124.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   retail['Country'][retail.Country=='EIRE'] = 'Eastern Ireland'

# %%
retail[retail.Country=='Eastern Ireland']
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 440      489520    35751C          PURPLE CURRENT CANDLE RING        12
# 441      489520    72739B        WHITE CHOCOLATE SCENT CANDLE        12
# 442      489520     22114   HOT WATER BOTTLE TEA AND SYMPATHY         8
# 443      489520     22212          FOUR HOOK  WHITE LOVEBIRDS         6
# 444      489520     21523  FANCY FONT HOME SWEET HOME DOORMAT         2
# ...         ...       ...                                 ...       ...
# 1064612  581433     22192               BLUE DINER WALL CLOCK         2
# 1064613  581433     48187                 DOORMAT NEW ENGLAND         2
# 1064614  581433     48184               DOORMAT ENGLISH ROSE          2
# 1064615  581433     20685               DOORMAT RED RETROSPOT         2
# 1064616  581433    79302M              ART LIGHTS,FUNK MONKEY         6
#
#                  InvoiceDate  Price  Customer ID          Country  \
# 440      2009-12-01 11:41:00   0.75      14911.0  Eastern Ireland
# 441      2009-12-01 11:41:00   1.25      14911.0  Eastern Ireland
# 442      2009-12-01 11:41:00   3.95      14911.0  Eastern Ireland
# 443      2009-12-01 11:41:00   2.10      14911.0  Eastern Ireland
# 444      2009-12-01 11:41:00   6.75      14911.0  Eastern Ireland
# ...                      ...    ...          ...              ...
# 1064612  2011-12-08 15:54:00   8.50      14911.0  Eastern Ireland
# 1064613  2011-12-08 15:54:00   8.25      14911.0  Eastern Ireland
# 1064614  2011-12-08 15:54:00   8.25      14911.0  Eastern Ireland
# 1064615  2011-12-08 15:54:00   8.25      14911.0  Eastern Ireland
# 1064616  2011-12-08 15:54:00   2.95      14911.0  Eastern Ireland
#
#                        date
# 440     2009-12-01 11:41:00
# 441     2009-12-01 11:41:00
# 442     2009-12-01 11:41:00
# 443     2009-12-01 11:41:00
# 444     2009-12-01 11:41:00
# ...                     ...
# 1064612 2011-12-08 15:54:00
# 1064613 2011-12-08 15:54:00
# 1064614 2011-12-08 15:54:00
# 1064615 2011-12-08 15:54:00
# 1064616 2011-12-08 15:54:00
#
# [16014 rows x 9 columns]

# %%
retail['StockCode'][retail.StockCode=='POST'] = 'post'
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\3314183796.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   retail['StockCode'][retail.StockCode=='POST'] = 'post'

# %%
retail[retail.StockCode=='post']
# Out:
#          Invoice StockCode Description  Quantity          InvoiceDate   Price  \
# 89        489439      post     POSTAGE         3  2009-12-01 09:28:00   18.00
# 126       489444      post     POSTAGE         1  2009-12-01 09:55:00  141.00
# 173       489447      post     POSTAGE         1  2009-12-01 10:10:00  130.00
# 625       489526      post     POSTAGE         6  2009-12-01 11:50:00   18.00
# 927      C489538      post     POSTAGE        -1  2009-12-01 12:18:00    9.58
# ...          ...       ...         ...       ...                  ...     ...
# 1066677   581494      post     POSTAGE         2  2011-12-09 10:13:00   18.00
# 1067191   581570      post     POSTAGE         1  2011-12-09 11:59:00   18.00
# 1067228   581574      post     POSTAGE         2  2011-12-09 12:09:00   18.00
# 1067229   581578      post     POSTAGE         3  2011-12-09 12:16:00   18.00
# 1067370   581587      post     POSTAGE         1  2011-12-09 12:50:00   18.00
#
#          Customer ID         Country                date
# 89           12682.0          France 2009-12-01 09:28:00
# 126          12636.0             USA 2009-12-01 09:55:00
# 173          12362.0         Belgium 2009-12-01 10:10:00
# 625          12533.0         Germany 2009-12-01 11:50:00
# 927          15796.0  United Kingdom 2009-12-01 12:18:00
# ...              ...             ...                 ...
# 1066677      12518.0         Germany 2011-12-09 10:13:00
# 1067191      12662.0         Germany 2011-12-09 11:59:00
# 1067228      12526.0         Germany 2011-12-09 12:09:00
# 1067229      12713.0         Germany 2011-12-09 12:16:00
# 1067370      12680.0          France 2011-12-09 12:50:00
#
# [1983 rows x 9 columns]

# %% [markdown]
# INDEXING

# %%
retail.reset_index(drop=True,inplace=True)

# %%
retail
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 797880  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 797881  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 797882  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 797883  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 797884  581587      post                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country
# 0       2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1       2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2       2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3       2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4       2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                     ...    ...          ...             ...
# 797880  2011-12-09 12:50:00   2.10      12680.0          France
# 797881  2011-12-09 12:50:00   4.15      12680.0          France
# 797882  2011-12-09 12:50:00   4.15      12680.0          France
# 797883  2011-12-09 12:50:00   4.95      12680.0          France
# 797884  2011-12-09 12:50:00  18.00      12680.0          France
#
# [797885 rows x 8 columns]

# %%
retail['date'] = pd.to_datetime(retail['InvoiceDate'])

# %%
retail
# Out:
#         level_0   index         Country                date Invoice StockCode  \
# 0             0       0  United Kingdom 2009-12-01 07:45:00  489434     85048
# 1             1       1  United Kingdom 2009-12-01 07:45:00  489434    79323P
# 2             2       2  United Kingdom 2009-12-01 07:45:00  489434    79323W
# 3             3       3  United Kingdom 2009-12-01 07:45:00  489434     22041
# 4             4       4  United Kingdom 2009-12-01 07:45:00  489434     21232
# ...         ...     ...             ...                 ...     ...       ...
# 797880   797880  797880          France 2011-12-09 12:50:00  581587     22899
# 797881   797881  797881          France 2011-12-09 12:50:00  581587     23254
# 797882   797882  797882          France 2011-12-09 12:50:00  581587     23255
# 797883   797883  797883          France 2011-12-09 12:50:00  581587     22138
# 797884   797884  797884          France 2011-12-09 12:50:00  581587      post
#
#                                 Description  Quantity          InvoiceDate  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00
# 1                        PINK CHERRY LIGHTS        12  2009-12-01 07:45:00
# 2                       WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00
# 3              RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00
# 4            STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00
# ...                                     ...       ...                  ...
# 797880         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09 12:50:00
# 797881        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09 12:50:00
# 797882      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09 12:50:00
# 797883        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09 12:50:00
# 797884                              POSTAGE         1  2011-12-09 12:50:00
#
#         Price  Customer ID
# 0        6.95      13085.0
# 1        6.75      13085.0
# 2        6.75      13085.0
# 3        2.10      13085.0
# 4        1.25      13085.0
# ...       ...          ...
# 797880   2.10      12680.0
# 797881   4.15      12680.0
# 797882   4.15      12680.0
# 797883   4.95      12680.0
# 797884  18.00      12680.0
#
# [797885 rows x 11 columns]

# %%
retail = retail.set_index('date')

# %%
retail.loc['2011']
# Out:
#                      level_0   index         Country Invoice StockCode  \
# date
# 2011-01-04 10:00:00   422634  422634  United Kingdom  539993     22386
# 2011-01-04 10:00:00   422635  422635  United Kingdom  539993     21499
# 2011-01-04 10:00:00   422636  422636  United Kingdom  539993     21498
# 2011-01-04 10:00:00   422637  422637  United Kingdom  539993     22379
# 2011-01-04 10:00:00   422638  422638  United Kingdom  539993     20718
# ...                      ...     ...             ...     ...       ...
# 2011-12-09 12:50:00   797880  797880          France  581587     22899
# 2011-12-09 12:50:00   797881  797881          France  581587     23254
# 2011-12-09 12:50:00   797882  797882          France  581587     23255
# 2011-12-09 12:50:00   797883  797883          France  581587     22138
# 2011-12-09 12:50:00   797884  797884          France  581587      post
#
#                                          Description  Quantity  \
# date
# 2011-01-04 10:00:00          JUMBO BAG PINK POLKADOT        10
# 2011-01-04 10:00:00               BLUE POLKADOT WRAP        25
# 2011-01-04 10:00:00              RED RETROSPOT WRAP         25
# 2011-01-04 10:00:00         RECYCLING BAG RETROSPOT          5
# 2011-01-04 10:00:00        RED RETROSPOT SHOPPER BAG        10
# ...                                              ...       ...
# 2011-12-09 12:50:00     CHILDREN'S APRON DOLLY GIRL          6
# 2011-12-09 12:50:00    CHILDRENS CUTLERY DOLLY GIRL          4
# 2011-12-09 12:50:00  CHILDRENS CUTLERY CIRCUS PARADE         4
# 2011-12-09 12:50:00    BAKING SET 9 PIECE RETROSPOT          3
# 2011-12-09 12:50:00                          POSTAGE         1
#
#                              InvoiceDate  Price  Customer ID
# date
# 2011-01-04 10:00:00  2011-01-04 10:00:00   1.95      13313.0
# 2011-01-04 10:00:00  2011-01-04 10:00:00   0.42      13313.0
# 2011-01-04 10:00:00  2011-01-04 10:00:00   0.42      13313.0
# 2011-01-04 10:00:00  2011-01-04 10:00:00   2.10      13313.0
# 2011-01-04 10:00:00  2011-01-04 10:00:00   1.25      13313.0
# ...                                  ...    ...          ...
# 2011-12-09 12:50:00  2011-12-09 12:50:00   2.10      12680.0
# 2011-12-09 12:50:00  2011-12-09 12:50:00   4.15      12680.0
# 2011-12-09 12:50:00  2011-12-09 12:50:00   4.15      12680.0
# 2011-12-09 12:50:00  2011-12-09 12:50:00   4.95      12680.0
# 2011-12-09 12:50:00  2011-12-09 12:50:00  18.00      12680.0
#
# [375251 rows x 10 columns]

# %%
retail = retail.reset_index()

# %%
retail
# Out:
#                       date Invoice StockCode  \
# 0      2009-12-01 07:45:00  489434     85048
# 1      2009-12-01 07:45:00  489434    79323P
# 2      2009-12-01 07:45:00  489434    79323W
# 3      2009-12-01 07:45:00  489434     22041
# 4      2009-12-01 07:45:00  489434     21232
# ...                    ...     ...       ...
# 797880 2011-12-09 12:50:00  581587     22899
# 797881 2011-12-09 12:50:00  581587     23254
# 797882 2011-12-09 12:50:00  581587     23255
# 797883 2011-12-09 12:50:00  581587     22138
# 797884 2011-12-09 12:50:00  581587      post
#
#                                 Description  Quantity          InvoiceDate  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00
# 1                        PINK CHERRY LIGHTS        12  2009-12-01 07:45:00
# 2                       WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00
# 3              RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00
# 4            STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00
# ...                                     ...       ...                  ...
# 797880         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09 12:50:00
# 797881        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09 12:50:00
# 797882      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09 12:50:00
# 797883        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09 12:50:00
# 797884                              POSTAGE         1  2011-12-09 12:50:00
#
#         Price  Customer ID         Country
# 0        6.95      13085.0  United Kingdom
# 1        6.75      13085.0  United Kingdom
# 2        6.75      13085.0  United Kingdom
# 3        2.10      13085.0  United Kingdom
# 4        1.25      13085.0  United Kingdom
# ...       ...          ...             ...
# 797880   2.10      12680.0          France
# 797881   4.15      12680.0          France
# 797882   4.15      12680.0          France
# 797883   4.95      12680.0          France
# 797884  18.00      12680.0          France
#
# [797885 rows x 9 columns]

# %%
retail_sorted = retail.set_index(['Country','date'])

# %%
retail_sorted
# Multilevel indexing
# Out:
#                                    Invoice StockCode  \
# Country        date
# United Kingdom 2009-12-01 07:45:00  489434     85048
#                2009-12-01 07:45:00  489434    79323P
#                2009-12-01 07:45:00  489434    79323W
#                2009-12-01 07:45:00  489434     22041
#                2009-12-01 07:45:00  489434     21232
# ...                                    ...       ...
# France         2011-12-09 12:50:00  581587     22899
#                2011-12-09 12:50:00  581587     23254
#                2011-12-09 12:50:00  581587     23255
#                2011-12-09 12:50:00  581587     22138
#                2011-12-09 12:50:00  581587      post
#
#                                                             Description  \
# Country        date
# United Kingdom 2009-12-01 07:45:00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00   6.95
# 1                   PINK CHERRY LIGHTS        12  2009-12-01 07:45:00   6.75
# 2                  WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00   6.75
# 3         RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00   2.10
# 4       STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00   1.25
#
#    Customer ID
# 0      13085.0
# 1      13085.0
# 2      13085.0
# 3      13085.0
# 4      13085.0

# %%
retail.groupby('Country').head()
# Out:
#                       date             Country Invoice StockCode  \
# 0      2009-12-01 07:45:00      United Kingdom  489434     85048
# 1      2009-12-01 07:45:00      United Kingdom  489434    79323P
# 2      2009-12-01 07:45:00      United Kingdom  489434    79323W
# 3      2009-12-01 07:45:00      United Kingdom  489434     22041
# 4      2009-12-01 07:45:00      United Kingdom  489434     21232
# ...                    ...                 ...     ...       ...
# 511759 2011-04-26 10:54:00  European Community  551013     22839
# 511760 2011-04-26 10:54:00  European Community  551013     22840
# 511761 2011-04-26 10:54:00  European Community  551013     22841
# 511762 2011-04-26 10:54:00  European Community  551013     22457
# 511763 2011-04-26 10:54:00  European Community  551013     22314
#
#                                 Description  Quantity          InvoiceDate  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00
# 1                        PINK CHERRY LIGHTS        12  2009-12-01 07:45:00
# 2                       WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00
# 3              RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00
# 4            STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00
# ...                                     ...       ...                  ...
# 511759      3 TIER CAKE TIN GREEN AND CREAM         1  2011-04-26 10:54:00
# 511760           ROUND CAKE TIN VINTAGE RED         2  2011-04-26 10:54:00
# 511761         ROUND CAKE TIN VINTAGE GREEN         2  2011-04-26 10:54:00
# 511762      NATURAL SLATE HEART CHALKBOARD          6  2011-04-26 10:54:00
# 511763          OFFICE MUG WARMER CHOC+BLUE         6  2011-04-26 10:54:00
#
#         Price  Customer ID
# 0        6.95      13085.0
# 1        6.75      13085.0
# 2        6.75      13085.0
# 3        2.10      13085.0
# 4        1.25      13085.0
# ...       ...          ...
# 511759  14.95      15108.0
# 511760   7.95      15108.0
# 511761   7.95      15108.0
# 511762   2.95      15108.0
# 511763   2.95      15108.0
#
# [205 rows x 9 columns]

# %%
# Total sales for each country
retail.groupby('Country')['Quantity'].sum()
# Out:
# Country
# Australia                103375
# Austria                   11306
# Bahrain                     755
# Belgium                   34598
# Brazil                      545
# Canada                     3657
# Channel Islands           20387
# Cyprus                    10652
# Czech Republic              592
# Denmark                  234764
# Eastern Ireland          309717
# European Community          497
# Finland                   14317
# France                   179959
# Germany                  221816
# Greece                     7707
# Iceland                    2967
# Israel                     5119
# Italy                     15122
# Japan                     30138
# Korea                       598
# Lebanon                     386
# Lithuania                  2306
# Malta                      2491
# Netherlands              381853
# Nigeria                     103
# Norway                    23528
# Poland                     5504
# Portugal                  27072
# RSA                         943
# Saudi Arabia                 75
# Singapore                  6987
# Spain                     44667
# Sweden                    87720
# Switzerland               51721
# Thailand                   2552
# USA                        3700
# United Arab Emirates       5721
# United Kingdom          8194318
# Unspecified                5099
# West Indies                 395
# Name: Quantity, dtype: int64

# %%
retail.groupby(['Country','Description'])['Quantity'].mean()
# Out:
# Country      Description
# Australia     DOLLY GIRL BEAKER                   200.0
#               I LOVE LONDON MINI BACKPACK           4.0
#              10 COLOUR SPACEBOY PEN                48.0
#              12 PENCIL SMALL TUBE WOODLAND        384.0
#              12 PENCILS SMALL TUBE RED SPOTTY      24.0
#                                                   ...
# West Indies  VINTAGE BEAD PINK SCARF                3.0
#              WHITE AND BLUE CERAMIC OIL BURNER      6.0
#              WOODLAND PARTY BAG + STICKER SET       1.0
#              WOVEN BERRIES CUSHION COVER            2.0
#              WOVEN FROST CUSHION COVER              2.0
# Name: Quantity, Length: 29514, dtype: float64

# %%
retail
# Out:
#                       date         Country Invoice StockCode  \
# 0      2009-12-01 07:45:00  United Kingdom  489434     85048
# 1      2009-12-01 07:45:00  United Kingdom  489434    79323P
# 2      2009-12-01 07:45:00  United Kingdom  489434    79323W
# 3      2009-12-01 07:45:00  United Kingdom  489434     22041
# 4      2009-12-01 07:45:00  United Kingdom  489434     21232
# ...                    ...             ...     ...       ...
# 797880 2011-12-09 12:50:00          France  581587     22899
# 797881 2011-12-09 12:50:00          France  581587     23254
# 797882 2011-12-09 12:50:00          France  581587     23255
# 797883 2011-12-09 12:50:00          France  581587     22138
# 797884 2011-12-09 12:50:00          France  581587      post
#
#                                 Description  Quantity          InvoiceDate  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00
# 1                        PINK CHERRY LIGHTS        12  2009-12-01 07:45:00
# 2                       WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00
# 3              RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00
# 4            STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00
# ...                                     ...       ...                  ...
# 797880         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09 12:50:00
# 797881        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09 12:50:00
# 797882      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09 12:50:00
# 797883        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09 12:50:00
# 797884                              POSTAGE         1  2011-12-09 12:50:00
#
#         Price  Customer ID
# 0        6.95      13085.0
# 1        6.75      13085.0
# 2        6.75      13085.0
# 3        2.10      13085.0
# 4        1.25      13085.0
# ...       ...          ...
# 797880   2.10      12680.0
# 797881   4.15      12680.0
# 797882   4.15      12680.0
# 797883   4.95      12680.0
# 797884  18.00      12680.0
#
# [797885 rows x 9 columns]

# %%
grouped = retail.groupby(['Country', 'Description'])[['Quantity', 'Price']].agg([np.mean,np.median])
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\3873146661.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped = retail.groupby(['Country', 'Description'])[['Quantity', 'Price']].agg([np.mean,np.median])
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\3873146661.py:1: FutureWarning: The provided callable <function median at 0x00000193B604C220> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped = retail.groupby(['Country', 'Description'])[['Quantity', 'Price']].agg([np.mean,np.median])
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\3873146661.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped = retail.groupby(['Country', 'Description'])[['Quantity', 'Price']].agg([np.mean,np.median])

# %%
grouped
# Out:
#                                               Quantity        Price
#                                                   mean median  mean median
# Country     Description
# Australia    DOLLY GIRL BEAKER                   200.0  200.0  1.08   1.08
#              I LOVE LONDON MINI BACKPACK           4.0    4.0  4.15   4.15
#             10 COLOUR SPACEBOY PEN                48.0   48.0  0.85   0.85
#             12 PENCIL SMALL TUBE WOODLAND        384.0  384.0  0.55   0.55
#             12 PENCILS SMALL TUBE RED SPOTTY      24.0   24.0  0.65   0.65
# ...                                                ...    ...   ...    ...
# West Indies VINTAGE BEAD PINK SCARF                3.0    3.0  7.95   7.95
#             WHITE AND BLUE CERAMIC OIL BURNER      6.0    6.0  1.25   1.25
#             WOODLAND PARTY BAG + STICKER SET       1.0    1.0  1.65   1.65
#             WOVEN BERRIES CUSHION COVER            2.0    2.0  4.95   4.95
#             WOVEN FROST CUSHION COVER              2.0    2.0  4.95   4.95
#
# [29514 rows x 4 columns]

# %%
grouped = grouped.sort_index()
grouped.loc[('Australia','10 COLOUR SPACEBOY PEN'),('Price','median')]
# Out:
# 0.85

# %%
grouped
# Out:
#                                               Quantity        Price
#                                                   mean median  mean median
# Country     Description
# Australia    DOLLY GIRL BEAKER                   200.0  200.0  1.08   1.08
#              I LOVE LONDON MINI BACKPACK           4.0    4.0  4.15   4.15
#             10 COLOUR SPACEBOY PEN                48.0   48.0  0.85   0.85
#             12 PENCIL SMALL TUBE WOODLAND        384.0  384.0  0.55   0.55
#             12 PENCILS SMALL TUBE RED SPOTTY      24.0   24.0  0.65   0.65
# ...                                                ...    ...   ...    ...
# West Indies VINTAGE BEAD PINK SCARF                3.0    3.0  7.95   7.95
#             WHITE AND BLUE CERAMIC OIL BURNER      6.0    6.0  1.25   1.25
#             WOODLAND PARTY BAG + STICKER SET       1.0    1.0  1.65   1.65
#             WOVEN BERRIES CUSHION COVER            2.0    2.0  4.95   4.95
#             WOVEN FROST CUSHION COVER              2.0    2.0  4.95   4.95
#
# [29514 rows x 4 columns]

# %%
a = retail.groupby(['Country','Description'])[['Quantity','Price']].agg([np.mean,np.median]).reset_index()
a
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\2083356288.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   a = retail.groupby(['Country','Description'])[['Quantity','Price']].agg([np.mean,np.median]).reset_index()
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\2083356288.py:1: FutureWarning: The provided callable <function median at 0x00000193B604C220> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   a = retail.groupby(['Country','Description'])[['Quantity','Price']].agg([np.mean,np.median]).reset_index()
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\2083356288.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   a = retail.groupby(['Country','Description'])[['Quantity','Price']].agg([np.mean,np.median]).reset_index()
#            Country                        Description Quantity        Price  \
#                                                           mean median  mean
# 0        Australia                  DOLLY GIRL BEAKER    200.0  200.0  1.08
# 1        Australia        I LOVE LONDON MINI BACKPACK      4.0    4.0  4.15
# 2        Australia             10 COLOUR SPACEBOY PEN     48.0   48.0  0.85
# 3        Australia      12 PENCIL SMALL TUBE WOODLAND    384.0  384.0  0.55
# 4        Australia   12 PENCILS SMALL TUBE RED SPOTTY     24.0   24.0  0.65
# ...            ...                                ...      ...    ...   ...
# 29509  West Indies           VINTAGE BEAD PINK SCARF       3.0    3.0  7.95
# 29510  West Indies  WHITE AND BLUE CERAMIC OIL BURNER      6.0    6.0  1.25
# 29511  West Indies   WOODLAND PARTY BAG + STICKER SET      1.0    1.0  1.65
# 29512  West Indies       WOVEN BERRIES CUSHION COVER       2.0    2.0  4.95
# 29513  West Indies          WOVEN FROST CUSHION COVER      2.0    2.0  4.95
#
#
#       median
# 0       1.08
# 1       4.15
# 2       0.85
# 3       0.55
# 4       0.65
# ...      ...
# 29509   7.95
# 29510   1.25
# 29511   1.65
# 29512   4.95
# 29513   4.95
#
# [29514 rows x 6 columns]

# %%
retail
# Out:
#                       date         Country Invoice StockCode  \
# 0      2009-12-01 07:45:00  United Kingdom  489434     85048
# 1      2009-12-01 07:45:00  United Kingdom  489434    79323P
# 2      2009-12-01 07:45:00  United Kingdom  489434    79323W
# 3      2009-12-01 07:45:00  United Kingdom  489434     22041
# 4      2009-12-01 07:45:00  United Kingdom  489434     21232
# ...                    ...             ...     ...       ...
# 797880 2011-12-09 12:50:00          France  581587     22899
# 797881 2011-12-09 12:50:00          France  581587     23254
# 797882 2011-12-09 12:50:00          France  581587     23255
# 797883 2011-12-09 12:50:00          France  581587     22138
# 797884 2011-12-09 12:50:00          France  581587      post
#
#                                 Description  Quantity          InvoiceDate  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12  2009-12-01 07:45:00
# 1                        PINK CHERRY LIGHTS        12  2009-12-01 07:45:00
# 2                       WHITE CHERRY LIGHTS        12  2009-12-01 07:45:00
# 3              RECORD FRAME 7" SINGLE SIZE         48  2009-12-01 07:45:00
# 4            STRAWBERRY CERAMIC TRINKET BOX        24  2009-12-01 07:45:00
# ...                                     ...       ...                  ...
# 797880         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09 12:50:00
# 797881        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09 12:50:00
# 797882      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09 12:50:00
# 797883        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09 12:50:00
# 797884                              POSTAGE         1  2011-12-09 12:50:00
#
#         Price  Customer ID
# 0        6.95      13085.0
# 1        6.75      13085.0
# 2        6.75      13085.0
# 3        2.10      13085.0
# 4        1.25      13085.0
# ...       ...          ...
# 797880   2.10      12680.0
# 797881   4.15      12680.0
# 797882   4.15      12680.0
# 797883   4.95      12680.0
# 797884  18.00      12680.0
#
# [797885 rows x 9 columns]

# %%
retail.groupby(['Country','Description']).agg(mean_qty = ('Quantity',np.mean),
                                              mean_price = ('Price' ,np.mean),
                                              median_qty = ('Quantity',np.median),
                                              median_price = ('Price',np.median)).reset_index()
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\135752670.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   retail.groupby(['Country','Description']).agg(mean_qty = ('Quantity',np.mean),
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\135752670.py:1: FutureWarning: The provided callable <function median at 0x00000193B604C220> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   retail.groupby(['Country','Description']).agg(mean_qty = ('Quantity',np.mean),
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\135752670.py:1: FutureWarning: The provided callable <function mean at 0x00000193B5F24AE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   retail.groupby(['Country','Description']).agg(mean_qty = ('Quantity',np.mean),
#            Country                        Description  mean_qty  mean_price  \
# 0        Australia                  DOLLY GIRL BEAKER     200.0        1.08
# 1        Australia        I LOVE LONDON MINI BACKPACK       4.0        4.15
# 2        Australia             10 COLOUR SPACEBOY PEN      48.0        0.85
# 3        Australia      12 PENCIL SMALL TUBE WOODLAND     384.0        0.55
# 4        Australia   12 PENCILS SMALL TUBE RED SPOTTY      24.0        0.65
# ...            ...                                ...       ...         ...
# 29509  West Indies           VINTAGE BEAD PINK SCARF        3.0        7.95
# 29510  West Indies  WHITE AND BLUE CERAMIC OIL BURNER       6.0        1.25
# 29511  West Indies   WOODLAND PARTY BAG + STICKER SET       1.0        1.65
# 29512  West Indies       WOVEN BERRIES CUSHION COVER        2.0        4.95
# 29513  West Indies          WOVEN FROST CUSHION COVER       2.0        4.95
#
#        median_qty  median_price
# 0           200.0          1.08
# 1             4.0          4.15
# 2            48.0          0.85
# 3           384.0          0.55
# 4            24.0          0.65
# ...           ...           ...
# 29509         3.0          7.95
# 29510         6.0          1.25
# 29511         1.0          1.65
# 29512         2.0          4.95
# 29513         2.0          4.95
#
# [29514 rows x 6 columns]

# %%
country_date_qty = retail[['Country','date','Quantity']]
country_date_qty.head()
# Out:
#           Country                date  Quantity
# 0  United Kingdom 2009-12-01 07:45:00        12
# 1  United Kingdom 2009-12-01 07:45:00        12
# 2  United Kingdom 2009-12-01 07:45:00        12
# 3  United Kingdom 2009-12-01 07:45:00        48
# 4  United Kingdom 2009-12-01 07:45:00        24

# %%
country_pivoted = pd.pivot_table(country_date_qty,index='date',columns = 'Country',values ='Quantity',fill_value = 0,aggfunc=np.sum)
# country_pivoted = country_pivoted.dropna()
country_pivoted = country_pivoted.reset_index()
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_23104\2087746452.py:1: FutureWarning: The provided callable <function sum at 0x00000193B5F039C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   country_pivoted = pd.pivot_table(country_date_qty,index='date',columns = 'Country',values ='Quantity',fill_value = 0,aggfunc=np.sum)

# %%
country_pivoted[['date','United Kingdom']]
# Out:
# Country                date  United Kingdom
# 0       2009-12-01 07:45:00             166
# 1       2009-12-01 07:46:00              60
# 2       2009-12-01 09:06:00             193
# 3       2009-12-01 09:08:00             145
# 4       2009-12-01 09:24:00             826
# ...                     ...             ...
# 41434   2011-12-09 12:23:00              76
# 41435   2011-12-09 12:25:00             120
# 41436   2011-12-09 12:31:00             278
# 41437   2011-12-09 12:49:00              66
# 41438   2011-12-09 12:50:00               0
#
# [41439 rows x 2 columns]

# %%
pd.melt(country_pivoted,id_vars=['date'],var_name=['Measure'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 pd.melt(country_pivoted,id_vars=['date'],var_name=['Measure'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\melt.py:100, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      96         var_name = [
#      97             frame.columns.name if frame.columns.name is not None else "variable"
#      98         ]
#      99 elif is_list_like(var_name):
# --> 100     raise ValueError(f"{var_name=} must be a scalar.")
#     101 else:
#     102     var_name = [var_name]
#
# ValueError: var_name=['Measure'] must be a scalar.

# %%
designation_data = pd.DataFrame({'name':['mike','jonathan','Mo','Lisa','Raj','Teo'],
                                'title':['manager','supervisor','director','associate','assistant','sectionhead']})
age_data = pd.DataFrame({'name':['mike','jonathan','Lee','Lisa','Tom','Teo'],
                                    'age':['40','50','34','25','60','29']})
designation_data
# Out:
#        name        title
# 0      mike      manager
# 1  jonathan   supervisor
# 2        Mo     director
# 3      Lisa    associate
# 4       Raj    assistant
# 5       Teo  sectionhead

# %%
age_data
# Out:
#        name age
# 0      mike  40
# 1  jonathan  50
# 2       Lee  34
# 3      Lisa  25
# 4       Tom  60
# 5       Teo  29

# %%
pd.merge(designation_data,age_data,how='left')
# Out:
#        name        title  age
# 0      mike      manager   40
# 1  jonathan   supervisor   50
# 2        Mo     director  NaN
# 3      Lisa    associate   25
# 4       Raj    assistant  NaN
# 5       Teo  sectionhead   29

# %%
pd.merge(designation_data,age_data,how='outer')
# Out:
#        name        title  age
# 0       Lee          NaN   34
# 1      Lisa    associate   25
# 2        Mo     director  NaN
# 3       Raj    assistant  NaN
# 4       Teo  sectionhead   29
# 5       Tom          NaN   60
# 6  jonathan   supervisor   50
# 7      mike      manager   40

# %%
pd.merge(designation_data,age_data,how='inner')
# Out:
#        name        title age
# 0      mike      manager  40
# 1  jonathan   supervisor  50
# 2      Lisa    associate  25
# 3       Teo  sectionhead  29

# %%
pd.merge(designation_data,age_data,how='right')
# Out:
#        name        title age
# 0      mike      manager  40
# 1  jonathan   supervisor  50
# 2       Lee          NaN  34
# 3      Lisa    associate  25
# 4       Tom          NaN  60
# 5       Teo  sectionhead  29
