# %%
import numpy as np
import pandas as pd

# %%
cars_data = pd.read_csv('C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\cars.csv')
cars_data
# Out:
#                                 name  sports_car    suv  wagon  minivan  \
# 0                 Chevrolet Aveo 4dr       False  False  False    False
# 1        Chevrolet Aveo LS 4dr hatch       False  False  False    False
# 2             Chevrolet Cavalier 2dr       False  False  False    False
# 3             Chevrolet Cavalier 4dr       False  False  False    False
# 4          Chevrolet Cavalier LS 2dr       False  False  False    False
# ..                               ...         ...    ...    ...      ...
# 423         Nissan Titan King Cab XE       False  False  False    False
# 424                      Subaru Baja       False  False  False    False
# 425                    Toyota Tacoma       False  False  False    False
# 426     Toyota Tundra Regular Cab V6       False  False  False    False
# 427  Toyota Tundra Access Cab V6 SR5       False  False  False    False
#
#      pickup  all_wheel  rear_wheel  Price  Dealer_Cost  Engine_size  \
# ...

# %%
cars_data.head()
# Out:
#                           name  sports_car    suv  wagon  minivan  pickup  \
# 0           Chevrolet Aveo 4dr       False  False  False    False   False
# 1  Chevrolet Aveo LS 4dr hatch       False  False  False    False   False
# 2       Chevrolet Cavalier 2dr       False  False  False    False   False
# 3       Chevrolet Cavalier 4dr       False  False  False    False   False
# 4    Chevrolet Cavalier LS 2dr       False  False  False    False   False
#
#    all_wheel  rear_wheel  Price  Dealer_Cost  Engine_size  cylenders  \
# 0      False       False  11690        10965          1.6          4
# 1      False       False  12585        11802          1.6          4
# 2      False       False  14610        13697          2.2          4
# 3      False       False  14810        13884          2.2          4
# 4      False       False  16385        15357          2.2          4
#
#    horsepower  city_miles_per_galloon  highway_miles_per_Gallon  weight  \
# ...

# %%
cars_data.describe()
# Out:
#                Price    Dealer_Cost  Engine_size   cylenders  horsepower  \
# count     428.000000     428.000000   428.000000  428.000000  428.000000
# mean    32774.855140   30014.700935     3.196729    5.775701  215.885514
# std     19431.716674   17642.117750     1.108595    1.622779   71.836032
# min     10280.000000    9875.000000     1.300000   -1.000000   73.000000
# 25%     20334.250000   18866.000000     2.375000    4.000000  165.000000
# 50%     27635.000000   25294.500000     3.000000    6.000000  210.000000
# 75%     39205.000000   35710.250000     3.900000    6.000000  255.000000
# max    192465.000000  173560.000000     8.300000   12.000000  500.000000
#
#        city_miles_per_galloon  highway_miles_per_Gallon       weight  \
# count              414.000000                414.000000   426.000000
# mean                20.089372                 26.905797  3577.213615
# std                  5.213062                  5.696804   760.437663
# ...

# %%
cars_data['cylenders'].nunique()
# Out:
# 8

# %%
cars_data['horsepower'].mean()
# Out:
# 215.8855140186916

# %%
cars_data['horsepower'].max()
# Out:
# 500

# %%
cars_data.shape[1]
# Out:
# 19

# %%
cars_data.horsepower.describe()
# Out:
# count    428.000000
# mean     215.885514
# std       71.836032
# min       73.000000
# 25%      165.000000
# 50%      210.000000
# 75%      255.000000
# max      500.000000
# Name: horsepower, dtype: float64

# %%
cars_data[cars_data.Price==max(cars_data.Price)].name
# Out:
# 287    Porsche 911 GT2 2dr
# Name: name, dtype: object

# %%
cars_data['car name'] = cars_data['name']

# %%
cars_data.head()
# Out:
#                           name  sports_car    suv  wagon  minivan  pickup  \
# 0           Chevrolet Aveo 4dr       False  False  False    False   False
# 1  Chevrolet Aveo LS 4dr hatch       False  False  False    False   False
# 2       Chevrolet Cavalier 2dr       False  False  False    False   False
# 3       Chevrolet Cavalier 4dr       False  False  False    False   False
# 4    Chevrolet Cavalier LS 2dr       False  False  False    False   False
#
#    all_wheel  rear_wheel  Price  Dealer_Cost  Engine_size  cylenders  \
# 0      False       False  11690        10965          1.6          4
# 1      False       False  12585        11802          1.6          4
# 2      False       False  14610        13697          2.2          4
# 3      False       False  14810        13884          2.2          4
# 4      False       False  16385        15357          2.2          4
#
#    horsepower  city_miles_per_galloon  highway_miles_per_Gallon  weight  \
# ...

# %%
cars_data.rename(columns={'name':'cars name'},inplace = True)

# %%
cars_data.head()
# Out:
#                      cars name  sports_car    suv  wagon  minivan  pickup  \
# 0           Chevrolet Aveo 4dr       False  False  False    False   False
# 1  Chevrolet Aveo LS 4dr hatch       False  False  False    False   False
# 2       Chevrolet Cavalier 2dr       False  False  False    False   False
# 3       Chevrolet Cavalier 4dr       False  False  False    False   False
# 4    Chevrolet Cavalier LS 2dr       False  False  False    False   False
#
#    all_wheel  rear_wheel  Price  Dealer_Cost  Engine_size  cylenders  \
# 0      False       False  11690        10965          1.6          4
# 1      False       False  12585        11802          1.6          4
# 2      False       False  14610        13697          2.2          4
# 3      False       False  14810        13884          2.2          4
# 4      False       False  16385        15357          2.2          4
#
#    horsepower  city_miles_per_galloon  highway_miles_per_Gallon  weight  \
# ...

# %%
car_pricing = cars_data[['cars name','Price']]
car_pricing
# Out:
#                            cars name  Price
# 0                 Chevrolet Aveo 4dr  11690
# 1        Chevrolet Aveo LS 4dr hatch  12585
# 2             Chevrolet Cavalier 2dr  14610
# 3             Chevrolet Cavalier 4dr  14810
# 4          Chevrolet Cavalier LS 2dr  16385
# ..                               ...    ...
# 423         Nissan Titan King Cab XE  26650
# 424                      Subaru Baja  24520
# 425                    Toyota Tacoma  12800
# 426     Toyota Tundra Regular Cab V6  16495
# 427  Toyota Tundra Access Cab V6 SR5  25935
#
# [428 rows x 2 columns]

# %%
def pricing_category(price):
    if(price<20000):
        return("Budget Car")
    elif((price>=20000) & (price<35000)):
        return("Suitable Car")
    else:
        return("Expensive Car")

# %%
car_pricing['category'] = 'NA'
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_320\1520201695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_pricing['category'] = 'NA'

# %%
car_pricing
# Out:
#                            cars name  Price Type category
# 0                 Chevrolet Aveo 4dr  11690   NA       NA
# 1        Chevrolet Aveo LS 4dr hatch  12585   NA       NA
# 2             Chevrolet Cavalier 2dr  14610   NA       NA
# 3             Chevrolet Cavalier 4dr  14810   NA       NA
# 4          Chevrolet Cavalier LS 2dr  16385   NA       NA
# ..                               ...    ...  ...      ...
# 423         Nissan Titan King Cab XE  26650   NA       NA
# 424                      Subaru Baja  24520   NA       NA
# 425                    Toyota Tacoma  12800   NA       NA
# 426     Toyota Tundra Regular Cab V6  16495   NA       NA
# 427  Toyota Tundra Access Cab V6 SR5  25935   NA       NA
#
# [428 rows x 4 columns]

# %%
car_pricing = car_pricing.drop(columns = ['Type'])

# %%
car_pricing
# Out:
#                            cars name  Price category
# 0                 Chevrolet Aveo 4dr  11690       NA
# 1        Chevrolet Aveo LS 4dr hatch  12585       NA
# 2             Chevrolet Cavalier 2dr  14610       NA
# 3             Chevrolet Cavalier 4dr  14810       NA
# 4          Chevrolet Cavalier LS 2dr  16385       NA
# ..                               ...    ...      ...
# 423         Nissan Titan King Cab XE  26650       NA
# 424                      Subaru Baja  24520       NA
# 425                    Toyota Tacoma  12800       NA
# 426     Toyota Tundra Regular Cab V6  16495       NA
# 427  Toyota Tundra Access Cab V6 SR5  25935       NA
#
# [428 rows x 3 columns]

# %%
for i in range(car_pricing.shape[0]):
    car_pricing.loc[i,'category'] = pricing_category(car_pricing.loc[i,'Price'])

car_pricing
# Out:
#                            cars name  Price      category
# 0                 Chevrolet Aveo 4dr  11690    Budget Car
# 1        Chevrolet Aveo LS 4dr hatch  12585    Budget Car
# 2             Chevrolet Cavalier 2dr  14610    Budget Car
# 3             Chevrolet Cavalier 4dr  14810    Budget Car
# 4          Chevrolet Cavalier LS 2dr  16385    Budget Car
# ..                               ...    ...           ...
# 423         Nissan Titan King Cab XE  26650  Suitable Car
# 424                      Subaru Baja  24520  Suitable Car
# 425                    Toyota Tacoma  12800    Budget Car
# 426     Toyota Tundra Regular Cab V6  16495    Budget Car
# 427  Toyota Tundra Access Cab V6 SR5  25935  Suitable Car
#
# [428 rows x 3 columns]

# %%
car_pricing['category'].value_counts()
# Out:
# category
# Suitable Car     193
# Expensive Car    137
# Budget Car        98
# Name: count, dtype: int64
