# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stocks = pd.read_csv("C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\stocks.csv")

# %%
stocks
# Out:
#             Date        AAPL         IBM        CSCO        MSFT
# 0     2000-01-03  111.937502  116.000000  108.062500  116.562500
# 1     2000-01-04  102.500003  112.062500  102.000000  112.625000
# 2     2000-01-05  103.999997  116.000000  101.687500  113.812500
# 3     2000-01-06   94.999998  114.000000  100.000000  110.000000
# 4     2000-01-07   99.500001  113.500000  105.875000  111.437500
# ...          ...         ...         ...         ...         ...
# 3516  2013-12-24  567.669975  183.220001   21.690001   37.080002
# 3517  2013-12-26  563.900009  185.350006   21.799999   37.439999
# 3518  2013-12-27  560.089989  185.080002   22.020000   37.290001
# 3519  2013-12-30  554.519981  186.410004   22.250000   37.290001
# 3520  2013-12-31  561.019997  187.570007   22.430000   37.410000
#
# [3521 rows x 5 columns]

# %%
stocks.columns
# Out:
# Index(['Date', 'AAPL', 'IBM', 'CSCO', 'MSFT'], dtype='object')

# %%
stocks['Date'] = pd.to_datetime(stocks['Date'])

# %%
sns.lineplot(x='Date',y='AAPL',data=stocks)
# Out:
# <Axes: xlabel='Date', ylabel='AAPL'>

# %%
plt.plot(stocks['Date'],stocks['AAPL'])
plt.title('Apple Stock')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(2,2,1)
plt.plot(stocks['Date'],stocks['AAPL'])
plt.title('Apple Stock')

plt.subplot(2,2,2)
plt.plot(stocks['Date'],stocks['CSCO'])
plt.title('Cisco Stock')

plt.subplot(2,2,3)
plt.plot(stocks['Date'],stocks['IBM'])
plt.title('IBM Stock')

plt.subplot(2,2,4)
plt.plot(stocks['Date'],stocks['MSFT'])
plt.title('Microsoft Stock')
plt.tight_layout()
plt.show()

# %%
stocks = stocks.set_index('Date')

# %%
stocks.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Scatterplots - used to capture relationship between 2 variables
cars = pd.read_csv("C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\cars.csv")

# %%
cars.head()
# Out:
#                           name  sports_car    suv  wagon  minivan  pickup  \
# 0           Chevrolet Aveo 4dr       False  False  False    False   False
# 1  Chevrolet Aveo LS 4dr hatch       False  False  False    False   False
# 2       Chevrolet Cavalier 2dr       False  False  False    False   False
# 3       Chevrolet Cavalier 4dr       False  False  False    False   False
# 4    Chevrolet Cavalier LS 2dr       False  False  False    False   False
#
#    all_wheel  rear_wheel  Price  Dealer_Cost  Engine_size  cylenders  \
# 0      False       False  11690        10965          1.6          4
# 1      False       False  12585        11802          1.6          4
# 2      False       False  14610        13697          2.2          4
# 3      False       False  14810        13884          2.2          4
# 4      False       False  16385        15357          2.2          4
#
#    horsepower  city_miles_per_galloon  highway_miles_per_Gallon  weight  \
# ...

# %%
cylinders = cars.cylenders.value_counts()
cylinders
# Out:
# cylenders
#  6     190
#  4     136
#  8      87
#  5       7
#  12      3
#  10      2
# -1       2
#  3       1
# Name: count, dtype: int64

# %%
cars_common = cars[cars.cylenders.isin([4,6,8])]

# %%
sns.scatterplot(x='horsepower',y='Price',data = cars_common)
# Out:
# <Axes: xlabel='horsepower', ylabel='Price'>

# %%
sns.scatterplot(x='horsepower',y='city_miles_per_galloon',data = cars_common,hue='cylenders')
# Out:
# <Axes: xlabel='horsepower', ylabel='city_miles_per_galloon'>

# %%
cars_common['cylenders'] = cars_common['cylenders'].astype('category')
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\926780030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_common['cylenders'] = cars_common['cylenders'].astype('category')

# %%
sns.scatterplot(x='horsepower',y='city_miles_per_galloon',data = cars_common,hue='cylenders')
# Out:
# <Axes: xlabel='horsepower', ylabel='city_miles_per_galloon'>

# %%
retail = pd.read_csv("C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\online_retail2 (1).csv")
retail = retail.drop_duplicates()
retail = retail.dropna(axis = 0, how = 'any')
retail.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
retail.Country.value_counts()
# Out:
# Country
# United Kingdom          716115
# Germany                  17339
# EIRE                     16014
# France                   13897
# Netherlands               5137
# Spain                     3754
# Belgium                   3110
# Switzerland               3058
# Portugal                  2414
# Australia                 1890
# Channel Islands           1646
# Italy                     1507
# Sweden                    1343
# Norway                    1308
# Cyprus                    1157
# Finland                   1049
# Austria                    938
# Denmark                    797
# Greece                     663
# Japan                      565
# USA                        535
# Poland                     527
# Unspecified                521
# United Arab Emirates       386
# Singapore                  346
# Israel                     321
# Malta                      299
# Canada                     228
# Iceland                    222
# Lithuania                  154
# ...

# %%
ire_france = retail[retail.Country.isin(['EIRE','France'])]

# %%
sns.countplot(x='Country',data=ire_france)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
ire_france['InvoiceDate'] = pd.to_datetime(ire_france['InvoiceDate'])
ire_france['dayofweek'] = ire_france['InvoiceDate'].dt.dayofweek
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\267801658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ire_france['InvoiceDate'] = pd.to_datetime(ire_france['InvoiceDate'])
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\267801658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ire_france['dayofweek'] = ire_france['InvoiceDate'].dt.dayofweek

# %%
ire_france['dayofweek']
# Out:
# 71         1
# 72         1
# 73         1
# 74         1
# 75         1
#           ..
# 1067366    4
# 1067367    4
# 1067368    4
# 1067369    4
# 1067370    4
# Name: dayofweek, Length: 29911, dtype: int32

# %%
week_dict = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}
ire_france['dayofweek'] = ire_france['dayofweek'].map(week_dict)
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\1650321325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ire_france['dayofweek'] = ire_france['dayofweek'].map(week_dict)

# %%
ire_france['dayofweek'].head()
# Out:
# 71    Tuesday
# 72    Tuesday
# 73    Tuesday
# 74    Tuesday
# 75    Tuesday
# Name: dayofweek, dtype: object

# %%
grouped = ire_france.groupby(['Country','dayofweek']).agg(total_quantity=('Quantity',np.sum)).reset_index()
grouped = grouped[grouped.total_quantity>=0]
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\567137257.py:1: FutureWarning: The provided callable <function sum at 0x00000224E7417600> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = ire_france.groupby(['Country','dayofweek']).agg(total_quantity=('Quantity',np.sum)).reset_index()

# %%
grouped
# Out:
#    Country  dayofweek  total_quantity
# 0     EIRE     Friday           45835
# 1     EIRE     Monday           47061
# 2     EIRE     Sunday           31796
# 3     EIRE   Thursday           72652
# 4     EIRE    Tuesday           54930
# 5     EIRE  Wednesday           57443
# 6   France     Friday           34814
# 7   France     Monday          111764
# 8   France     Sunday           15321
# 9   France   Thursday           41462
# 11  France  Wednesday           35035

# %%
sns.barplot(x='dayofweek',y='total_quantity',data = grouped,hue='Country')
# Out:
# <Axes: xlabel='dayofweek', ylabel='total_quantity'>

# %%
#Distribution Plots

# %%
iris = pd.read_csv("C:\\Users\\Khush Bhuta\\Desktop\\python_workspace\\data\\iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(iris.sepal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.kdeplot(iris.sepal_length[iris.species=='virginica'],label = 'Virginica')
sns.kdeplot(iris.sepal_length[iris.species=='setosa'],label = 'setosa')
sns.kdeplot(iris.sepal_length[iris.species=='versicolor'],label = 'Versicolor')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(x='species',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x='species',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(x='cylenders',y='horsepower',data=cars_common)
# Out:
# <Axes: xlabel='cylenders', ylabel='horsepower'>

# %%
plt.hist(x=iris.sepal_length,bins=30)
# Out:
# (array([ 4.,  1.,  4.,  2.,  5., 16.,  9.,  4.,  1.,  6., 13.,  8.,  7.,
#          3.,  6., 10.,  9.,  7.,  5.,  2., 11.,  4.,  1.,  1.,  4.,  1.,
#          0.,  1.,  4.,  1.]),
#  array([4.3 , 4.42, 4.54, 4.66, 4.78, 4.9 , 5.02, 5.14, 5.26, 5.38, 5.5 ,
#         5.62, 5.74, 5.86, 5.98, 6.1 , 6.22, 6.34, 6.46, 6.58, 6.7 , 6.82,
#         6.94, 7.06, 7.18, 7.3 , 7.42, 7.54, 7.66, 7.78, 7.9 ]),
#  <BarContainer object of 30 artists>)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot(iris.sepal_length,bins=30,kde=False)
# Out:
# C:\Users\Khush Bhuta\AppData\Local\Temp\ipykernel_26700\1263220297.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris.sepal_length,bins=30,kde=False)
# <Axes: xlabel='sepal_length'>

# %%
sns.pairplot(iris,hue='species')

# %%
cars_common.columns
# Out:
# Index(['name', 'sports_car', 'suv', 'wagon', 'minivan', 'pickup', 'all_wheel',
#        'rear_wheel', 'Price', 'Dealer_Cost', 'Engine_size', 'cylenders',
#        'horsepower', 'city_miles_per_galloon', 'highway_miles_per_Gallon',
#        'weight', 'base_wheeel', 'length', 'width'],
#       dtype='object')

# %%
sns.pairplot(cars_common[['horsepower','sports_car','Price','city_miles_per_galloon','cylenders']],hue='cylenders')
